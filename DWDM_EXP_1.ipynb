# %% [markdown]
# <a href="https://colab.research.google.com/github/Arja-Balu/DWDM/blob/main/DWDM_EXP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('collegePlace.csv')
data.head(5)
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22    Male  Electronics And Communication            1     8       1
# 1   21  Female               Computer Science            0     7       1
# 2   22  Female         Information Technology            1     6       0
# 3   21    Male         Information Technology            0     8       0
# 4   22    Male                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  PlacedOrNot
# 0                  1            1
# 1                  1            1
# 2                  0            1
# 3                  1            1
# 4                  0            1

# %%
null_count = data.isnull().sum()
print(null_count)
# Out:
# Age                  0
# Gender               0
# Stream               0
# Internships          0
# CGPA                 0
# Hostel               0
# HistoryOfBacklogs    0
# PlacedOrNot          0
# dtype: int64

# %%
#since there are no null values we can procced to next process

# %%
print(data.columns)
# Out:
# Index(['Age', 'Gender', 'Stream', 'Internships', 'CGPA', 'Hostel',
#        'HistoryOfBacklogs', 'PlacedOrNot'],
#       dtype='object')

# %%
Y=data['PlacedOrNot']
X=data.drop('PlacedOrNot',axis=1)

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: PlacedOrNot, dtype: int64

# %%
X.head()
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22    Male  Electronics And Communication            1     8       1
# 1   21  Female               Computer Science            0     7       1
# 2   22  Female         Information Technology            1     6       0
# 3   21    Male         Information Technology            0     8       0
# 4   22    Male                     Mechanical            0     8       1
#
#    HistoryOfBacklogs
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  0
